# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Wed Apr 13 02:58:11 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   31C    P0    26W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %% [markdown]
# ## Install Requirements on Colab

# %%
# !pip install records jsonlines

# %% [markdown]
# ## Generate Enhanced Knowledge
#
# We use NL2SQL-RULE as basics to generate our additional agg-enhanced knowledge

# %%
# !cd drive/MyDrive/models/ATEP/ && python add_agg_knowledge.py dev
# Out:
# vocab size: 30522
# hidden_size: 768
# num_hidden_layer: 12
# num_attention_heads: 12
# hidden_act: gelu
# intermediate_size: 3072
# hidden_dropout_prob: 0.1
# attention_probs_dropout_prob: 0.1
# max_position_embeddings: 512
# type_vocab_size: 2
# initializer_range: 0.02
# Load pre-trained parameters.
# success = 1060 not_added = 7347 error = 14

# %% [markdown]
# ## Start Training
#
# add argument `--agg_enhanced 1` to use agg-enhanced dataset，`--EG 1` to use Execution Guided Decoding，`--trained True` to enable trained model

# %%
# !cd drive/MyDrive/models/ATEP/ && python main.py --tepoch 50 --train_size 400 --test_size 200 --agg_enhanced 1 --EG 0
# Out:
# BERT-type: uncased_L-12_H-768_A-12
# Batch_size = 8
# BERT parameters:
# learning rate: 1e-05
# Fine-tune BERT: True
# vocab size: 30522
# hidden_size: 768
# num_hidden_layer: 12
# num_attention_heads: 12
# hidden_act: gelu
# intermediate_size: 3072
# hidden_dropout_prob: 0.1
# attention_probs_dropout_prob: 0.1
# max_position_embeddings: 512
# type_vocab_size: 2
# initializer_range: 0.02
# Load pre-trained parameters.
# Seq-to-SQL: the number of final BERT layers to be used: 2
# Seq-to-SQL: the size of hidden dimension = 100
# Seq-to-SQL: LSTM encoding layer size = 2
# Seq-to-SQL: dropout rate = 0.3
# Seq-to-SQL: learning rate = 0.001
# Execution Guided Decoding: 0
# total epoch= 50  |  train_size= 400  |  test_size= 200
# train results ------------
#  Epoch: 0, ave loss: 1.7435075023025275, acc_sc: 0.769, acc_sa: 0.794, acc_wn: 0.850,         acc_wc: 0.736, acc_wo: 0.760, acc_wv: 0.613, acc_lx: 0.389, acc_x: 0.469
# dev results ------------
# ...

# %% [markdown]
# ## NL2SQL-RULE
#
# use base model NL2SQL-RULE's results for comparision

# %%
# !cd drive/MyDrive/models/NL2SQL-RULE/ && python main.py --tepoch 50 --train_size 400 --test_size 200 --agg_enhanced 0 --EG 0
# Out:
# BERT-type: uncased_L-12_H-768_A-12
# Batch_size = 8
# BERT parameters:
# learning rate: 1e-05
# Fine-tune BERT: True
# vocab size: 30522
# hidden_size: 768
# num_hidden_layer: 12
# num_attention_heads: 12
# hidden_act: gelu
# intermediate_size: 3072
# hidden_dropout_prob: 0.1
# attention_probs_dropout_prob: 0.1
# max_position_embeddings: 512
# type_vocab_size: 2
# initializer_range: 0.02
# Load pre-trained parameters.
# Seq-to-SQL: the number of final BERT layers to be used: 2
# Seq-to-SQL: the size of hidden dimension = 100
# Seq-to-SQL: LSTM encoding layer size = 2
# Seq-to-SQL: dropout rate = 0.3
# Seq-to-SQL: learning rate = 0.001
# Execution Guided Decoding: 0
# total epoch= 50  |  train_size= 400  |  test_size= 200
# train results ------------
#  Epoch: 0, ave loss: 1.7931431540474296, acc_sc: 0.768, acc_sa: 0.744, acc_wn: 0.835,         acc_wc: 0.720, acc_wo: 0.729, acc_wv: 0.592, acc_lx: 0.347, acc_x: 0.427
# dev results ------------
# ...
